# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c179bfe87064> in <module>
# ----> 1 import cv2
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'cv2'

# %%
py -m pip install opencv-python
# Out:
#   File "<ipython-input-2-06a9ff4cf3c6>", line 1
#     py -m pip install opencv-python
#           ^
# SyntaxError: invalid syntax

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
immport numpy as np
# Out:
#   File "<ipython-input-4-52f176afc656>", line 1
#     immport numpy as np
#             ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# %%
np.random.seed(66)
arr=np.random.randint(0,255,size=(6,6))

# %%
arr
# Out:
# array([[ 20,  60, 119,  51, 122, 205],
#        [ 79,  90, 149,  51, 202, 205],
#        [144,  39, 141, 253, 221,  27],
#        [ 75, 230, 175, 159,  90,  74],
#        [ 32, 210, 210,   2,   6,  32],
#        [187,  12, 184,  40, 254,   9]])

# %%
sky=cv2.imread('Original.jpg')
sky_rgb=np.copy(sky)
sky_rgb=cv2.cvtColor(sky_rgb,cv2.COLOR_BGR2RGB)
plt.imshow(sky_rgb)

# %%
sky_gray=np.copy(sky)
sky_gray=cv2.cvtColor(sky_gray,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(sky_gray,cmap='gray')

# %%
sky_gray.shape
# Out:
# (4032, 3024)

# %%
cv2.minMaxLoc(sky_gray)
# Out:
# (1.0, 255.0, (1586, 2338), (1590, 2324))
